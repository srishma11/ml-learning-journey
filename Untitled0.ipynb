# %% [markdown]
# <a href="https://colab.research.google.com/github/srishma11/ml-learning-journey/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1,2,3,4,5])
print(a)
print(a.mean())
print(a.sum())
print(a.reshape(5,1))
# Out:
# [1 2 3 4 5]
# 3.0
# 15
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
import pandas as pd
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ages = [22, 15, 35, 8, 45]
for age in ages:
    if age >= 18:
        print(age, "is an adult")
    else:
        print(age, "is a minor")
# Out:
# 22 is an adult
# 15 is a minor
# 35 is an adult
# 8 is a minor
# 45 is an adult

# %%
survived = [1, 0, 1, 1, 0]
for result in survived:
    if result == 1:
       print("survived")
    else:
       print("did not survive")
# Out:
# survived
# did not survive
# survived
# survived
# did not survive

# %%
for result in df['Survived'][:10]:
    if result == 1:
       print("survived")
    else:
       print("did not survive")
# Out:
# did not survive
# survived
# survived
# survived
# did not survive
# did not survive
# did not survive
# did not survive
# survived
# survived

# %%
count = 0
for x in df['Survived'][:10]:
    if x == 1:
       count = count + 1

print("total survived:", count)
# Out:
# total survived: 5

# %%
import matplotlib.pyplot as plt
df['Survived'].value_counts().plot(kind='bar')
plt.title('Survived vs did not survive')
plt.show()

# %%
df['Age'].plot(kind='hist')
plt.title('Age distribution of passengers')
plt.show()
